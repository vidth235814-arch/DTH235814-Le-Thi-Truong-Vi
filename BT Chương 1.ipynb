# %%
 print("Chao cac ban! ")
# Out:
# Chao cac ban!

# %%
print("Le Thi Truong Vi")
# Out:
# Le Thi Truong Vi

# %%
print("Minh ve minh co nho ta?")
print("\nMuoi lam nam ay thiet tha man nong.")
print("\nMinh ve minh co nho khong?")
print("\nNhin cay nho nui, nhin song nho nguon")
# Out:
# Minh ve minh co nho ta?
#
# Muoi lam nam ay thiet tha man nong.
#
# Minh ve minh co nho khong?
#
# Nhin cay nho nui, nhin song nho nguon

# %%
print("****")
print("\n*  *")
print("\n*  *")
print("\n****")
# Out:
# ****
#
# *  *
#
# *  *
#
# ****

# %%
print("*********")
print("\n*********")
print("\n*********")
# Out:
# *********
#
# *********
#
# *********

# %%
print("     *     ")
print("\n    ***    ")
print("\n  *******  ")
print("\n    ***    ")
print("\n   *****   ")
print("\n***********")
print("\n    * *    ")
print("\n    * *    ")
# Out:
#      *
#
#     ***
#
#   *******
#
#     ***
#
#    *****
#
# ***********
#
#     * *
#
#     * *

# %%
print(" Toi la ChatGPT.")
# Out:
#  Toi la ChatGPT.
